# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
from datetime import datetime, timedelta

x = np.arange(1,11,1)
plt.plot(x, x)
ax = plt.gca()
# 调整坐标轴显示的刻度
# ax.locator_params(nbins=10)
# ax.locator_params('x', nbins=20)
# ax.locator_params('y', nbins=5)

plt.locator_params('x', nbins=20)
plt.locator_params('y', nbins=5)

# %%
start = datetime(2019,1,1)
stop = datetime(2020,1,1)
delta = timedelta(days=1)

fig = plt.figure()

dates = mpl.dates.drange(start, stop, delta)

y = np.random.rand(len(dates))
ax = fig.gca()
day = (stop-start).days
month = (stop-start).days / 12
# print((stop-start).days)
# ax.locator_params('x', nbins=day)
# ax.plot(dates,y);
ax.plot_date(dates, y, linestyle='-',marker='');

date_format = mpl.dates.DateFormatter('%Y-%m')
ax.xaxis.set_major_formatter(date_format)
fig.autofmt_xdate()

# %run matplotlib_intro_016_坐标轴刻度.ipynb
