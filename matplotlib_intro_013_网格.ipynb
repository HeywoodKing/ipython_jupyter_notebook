# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

x  = np.arange(2,5)
plt.plot(x, x*2);
# plt.grid(True)
# plt.grid(color='r', linewidth=0.2, linestyle='-')
# plt.grid(color='r', linewidth=0.2, linestyle='-.')
plt.grid(color='r', linewidth=0.2, linestyle='--')

# %%
x = np.arange(0, 10, 1)
fig = plt.figure()
ax = fig.add_subplot(111)
plt.plot(x, x*2);
ax.grid(color='r')
