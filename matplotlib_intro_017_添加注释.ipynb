# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.arange(-10,11,1)
y = x*x

plt.plot(x, y);
plt.annotate('this is the bottom', xy=(0,1), xytext=(-3,50),arrowprops=dict(facecolor='r',frac=0.1,headwidth=8,width=1));
