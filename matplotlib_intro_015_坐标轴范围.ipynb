# %%
import numpy as np 
import matplotlib.pyplot as plt 
# %matplotlib inline

# x = np.random.random(10)
x = np.arange(-10, 11, 1) 
plt.plot(x, x*x); 

# plt.axis([-10,10, 0, 20])

# plt.xlim([-10,10])
# plt.ylim([0, 20])

plt.xlim(xmin=-5)
# plt.xlim(xmin=-5,xmax=5)

# plt.ylim(ymin=0)
plt.ylim(ymin=0, ymax=30)
# Out:
# (0, 30)
